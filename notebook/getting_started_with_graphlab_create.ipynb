# %% [markdown]
# # Welcome to GraphLab Create
#
# ## First a note about IPython Notebook
# Most of our tutorials are written as IPython notebooks. This allows you to download and run the tutorials on your own machine, either as notebooks (.ipynb) or Python files (.py). To run the notebooks you'll need to install IPython and IPython Notebook; for installation details, visit [www.ipython.org](http://www.ipython.org). Several of the notebooks also depend on [matplotlib](http://matplotlib.org/) and [NetworkX](http://networkx.github.io/) for plotting. These can be installed with 'pip install matplotlib' and 'pip install networkx'.
#
# ## Overview
# In this tutorial, you'll get a good flavor of some of the fundamental tasks that GraphLab Create is built for.
#
# You will learn how to:
#
# * load data into SFrames
# * create a Graph data structure from these frames
# * write simple graph queries
# * apply a machine learning model from the Graph Analytics Toolkit
#
# ...oh yeah, you'll also learn that some of us at GraphLab have a thing for Bond...yes...James Bond...

# %%
import graphlab as gl

# %% [markdown]
# # Load data into an SFrame
# GraphLab Create uses two scalable data structures:
#
# - the SFrame, a tabular structure ideal for data munging & feature building
# - the Graph, a structure ideal for sparse data

# %%
vertices = gl.SFrame.read_csv('http://s3.amazonaws.com/GraphLab-Datasets/bond/bond_vertices.csv')
edges = gl.SFrame.read_csv('http://s3.amazonaws.com/GraphLab-Datasets/bond/bond_edges.csv')
# Out:
# [INFO] GraphLab Server Version: 0.1.0

# %%
# SFrame has a number of methods to explore and transform your data
vertices.head()
# Out:
#              name gender license_to_kill villian
# 0      James Bond      M               1       0
# 1               M      M               1       0
# 2      Moneypenny      F               1       0
# 3               Q      M               1       0
# 4         Wai Lin      F               1       0
# 5  Inga Bergstorm      F               0       0
# 6   Elliot Carver      M               0       1
# 7    Paris Carver      F               0       1
# 8       Gotz Otto      M               0       1
# 9     Henry Gupta      M               0       1
#
# [10 rows x 4 columns]

# %%
# this shows the summary of the edges SFrame
edges
# Out:
# Columns:
# 	src	str
# 	dst	str
# 	relation	str
#
# Rows: 20
#
# Data:
#               src         dst    relation
# 0         Wai Lin  James Bond      friend
# 1               M  James Bond    worksfor
# 2  Inga Bergstorm  James Bond      friend
# 3   Elliot Carver  James Bond   killed_by
# 4       Gotz Otto  James Bond   killed_by
# 5      James Bond           M  managed_by
# 6               Q           M  managed_by
# 7      Moneypenny           M  managed_by
# 8               Q  Moneypenny   colleague
# 9               M  Moneypenny    worksfor
#
# ...
# [20 rows x 3 columns]

# %% [markdown]
# # Create a graph object

# %%
g = gl.Graph()

# %% [markdown]
# # Add vertices and edges to this graph

# %%
# add some vertices in a dataflow-ish way
g = g.add_vertices(vertices=vertices, vid_field='name')

# %%
# more dataflow
g = g.add_edges(edges=edges, src_field='src', dst_field='dst')

# %% [markdown]
# # Do some basic graph querying

# %%
# Show all the vertices
g.get_vertices()
# Out:
# Columns:
# 	__id	str
# 	gender	str
# 	license_to_kill	str
# 	villian	str
#
# Rows: 10
#
# Data:
#              __id gender license_to_kill villian
# 0    Paris Carver      F               0       1
# 1   Elliot Carver      M               0       1
# 2               Q      M               1       0
# 3      Moneypenny      F               1       0
# 4       Gotz Otto      M               0       1
# 5               M      M               1       0
# 6      James Bond      M               1       0
# 7         Wai Lin      F               1       0
# 8     Henry Gupta      M               0       1
# 9  Inga Bergstorm      F               0       0
#
# [10 rows x 4 columns]

# %%
# Show all the edges in dataframe
g.get_edges().to_dataframe()
# Out:
#       relation        __src_id        __dst_id
# 0    engagedto   Elliot Carver    Paris Carver
# 1    killed_by       Gotz Otto      James Bond
# 2    killed_by   Elliot Carver      James Bond
# 3    killed_by    Paris Carver   Elliot Carver
# 4    colleague      Moneypenny               Q
# 5       friend  Inga Bergstorm      James Bond
# 6     worksfor   Elliot Carver     Henry Gupta
# 7     worksfor   Elliot Carver       Gotz Otto
# 8   managed_by      James Bond               M
# 9       friend      James Bond         Wai Lin
# 10  managed_by               Q               M
# 11   killed_by     Henry Gupta   Elliot Carver
# 12    worksfor               M      Moneypenny
# 13    worksfor               M               Q
# 14      friend      James Bond  Inga Bergstorm
# 15  managed_by      Moneypenny               M
# 16   engagedto    Paris Carver   Elliot Carver
# 17    worksfor               M      James Bond
# 18   colleague               Q      Moneypenny
# 19      friend         Wai Lin      James Bond
#
# [20 rows x 3 columns]

# %%
# Get all the "friend" edges
g.get_edges(fields={'relation': 'friend'})
# Out:
# Columns:
# 	relation	str
# 	__src_id	str
# 	__dst_id	str
#
# Rows: 4
#
# Data:
#   relation        __src_id        __dst_id
# 0   friend      James Bond  Inga Bergstorm
# 1   friend      James Bond         Wai Lin
# 2   friend  Inga Bergstorm      James Bond
# 3   friend         Wai Lin      James Bond
#
# [4 rows x 3 columns]

# %% [markdown]
# # GraphLab Create has application oriented toolkits
#
# ### Today, there are three:
#
# * Graph Analytics (graphlab.toolkits.graph_analytics) -  this is where pagerank lives
# * Recommender Systems (graphlab.toolkits.recommender) -  this is where models like item-similarity, matrix factorization, popularity, etc. live
# * Clustering (graphlab.toolkits.clustering) - this is where models like kmeans live
#
# # Apply the pagerank algorithm to our graph

# %%
pr = gl.pagerank.create(g)

# %%
pr.get('pagerank').topk(column_name='pagerank')
# Out:
#              __id  pagerank
# 0      James Bond  2.526803
# 1               M  1.855536
# 2      Moneypenny  1.173976
# 3               Q  1.172331
# 4         Wai Lin  0.863250
# 5  Inga Bergstorm  0.863250
# 6   Elliot Carver  0.651303
# 7    Paris Carver  0.288402
# 8       Gotz Otto  0.288402
# 9     Henry Gupta  0.288402
#
# [10 rows x 2 columns]

# %% [markdown]
# ### We see, not unexpectedly, that James Bond is a very important person, and that bad guys aren't that popular...
#
# (Looking for more details about the modules and functions? Check out the <a href="/products/create/docs/">API docs</a>.)
